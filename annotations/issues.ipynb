# %% [markdown]
# ## Issues

# %% [markdown]
# Issue is a record describing a problem or other phenomena localized in a specific area of the scene.
# Issue is represented as a set of labels, typically including:
#
# 1. Location:
#    1. dataset
#    2. scene
#    3. additional labels identifying scene (together referred below as Scene)
#    4. area (polygon)
# 2. Categorization:
#    1. category (unique code of the issue type)
#    2. description of the category (cat_description)
#    3. visualization hints of the category (optional, each with its own label)
# 3. Issue Specific Descriptions (optional):
#    1. description - textual description
#    2. numerical descriptors (each with its own label) - e.g. number of pixel in the area.
#    3. optional visualization hints  (each with its own label)

# %% [markdown]
# ### Code Structure

# %% [markdown]
# Collection of issues is managed by class IssueCollection, which is maintaining a DataFrame catalog of issues as rows,
# and allowing to add, remove, search and show issues.
#
# In particular:
# ```issues.qix()``` query create another instance of Issues with requested subset of the issues.
#
# Visualization of issues is created by class VisIssue.
#
# ```vis_issue(issues, fig, axes_queries: list[Axes] | Axes | list[tuple[Axes, SceneLabels]])```
#
# 1. vis_issue.show() - displays issues from scenes associated with given axes.
# 2. The association may be either explicit when axes are list of tuples, or implicit if an axis carries a particular attribute  ```axis._scene_labels: SceneLabels```
# 3. ```Issues.SCENE_LABELS='_scene_labels'```
# 4. ```Issues.attach_label(obj: object | list[objects], labels)-> object | list[objects]```
#    1. Helper class method to attach SCENE_LABELS attribute to given object(s)

# %% [markdown]
# ### Use Cases:

# %% [markdown]
# Below we assume that:
#
# 1. scene includes all the identifiers, like dataset, scene, etc
#
# 2. there are multiple visualizers producing  matplotlib.pyplot.Figure

# %%
# %matplotlib widget
import matplotlib as mpl

mpl.rcParams['figure.dpi'] = 80
import warnings
warnings.filterwarnings('ignore')
from inu.visual.insight import imgrid
from inu.visual.annotations import IssueCollection, VisIssue, show_issues_on_scenes
from inu.utils.label import Labels
from inu.pipelines.benchmark.core import Benchmark
from inu.env import setup
setup(
      debug=['resman', 'engine', 'bmk', 'datacast'], 
      info=['engine'],
      )
from inu.datacast import resman
resman.get("col").discover("/sp/code/algodev/resources/collections/", cache=False)
# Out:
# (!) ---> Log file: /tmp/logs/algodev.log
# 1

# %%
bm = Benchmark('enhance_gm_v4_selector')
bm.exec_pipeline(measure=False)
alg_name = 'MoFcV4_4_UC_select_3_class'
# Out:
# ---------------------------------------------------------------------------
# ResNotFoundError                          Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 bm = Benchmark('enhance_gm_v4_selector')
#       2 bm.exec_pipeline(measure=False)
#       3 alg_name = 'MoFcV4_4_UC_select_3_class'
#
# File /sp/code/algodev/inu/pipelines/benchmark/core.py:357, in Benchmark.__init__(self, name, description, adapter, process, inputs, prevaluation, evaluation, measurement, scores, data_root, cache, evals_dir, evals_sink_dir, results_dir, **kws)
#     349 def __init__(self, name: str | BenchmarkRM = None, *, description: str = None,
#     350              adapter: str = None, process: dict = None, inputs: dict = None,
#     351              prevaluation: dict = None,
#    (...)
#     354              evals_dir: PathT = None, evals_sink_dir: PathT = None, results_dir: PathT = None,
#     355              **kws):
# --> 357     self.config = BenchmarkRM.from_config(locals(), undefined=False, ignore=True)
#     358     self.adapt = BMarkAdaptInterface.from_module(self.config.adapter)
#     360     self.dm = self.adapt.data_model
#
# File /sp/code/algodev/inu/resman/resource.py:254, in ResourceModel.from_config(cls, cfg, ignore, undefined)
#     252     if not undefined:
#     253         cfg = drop_undef(ns=cfg)
# --> 254     return cls(**cfg)
#     256 raise TypeError(f"Unexpected config type={type(cfg)} for {cls}")
#
# File /sp/code/algodev/inu/resman/resource.py:201, in ResourceModel.__init__(self, name, **cfg)
#     199     if cfg:
#     200         raise RuntimeError("Resource constructor received both model instance and config!")
# --> 201 elif not cfg and not (res := self._manager.find_resource(name, valid=True)):
#     202     _log.debug(f"Can't locate {self._kind_name} by {name = }. Continue to construction...")
#     204 if res:  # copy-construction
#
# File /sp/code/algodev/inu/resman/resource.py:810, in ResManager.find_resource(self, name, valid, fail, as_cfg, auto_scan, fuzzy)
#     808 if info:
#     809     if valid or not as_cfg:
# --> 810         info.validate()
#     811     return info.cfg if as_cfg else info.res
#     813 if fail:
#
# File /sp/code/algodev/inu/resman/resource.py:408, in ResManager.RegInfo.validate(self)
#     404 """Validate resource if needed and update cfg.
#     405 :return: res
#     406 """
#     407 if not self.res:
# --> 408     self.res = self._model.validate(self.cfg)
#     409     self.cfg = self.res.dict()
#     410 return self.res
#
# File ~/miniconda3/envs/algodev/lib/python3.11/site-packages/pydantic/main.py:711, in BaseModel.validate(cls, value)
#     708 value = cls._enforce_dict_if_root(value)
#     710 if isinstance(value, dict):
# --> 711     return cls(**value)
#     712 elif cls.__config__.orm_mode:
#     713     return cls.from_orm(value)
#
# File /sp/code/algodev/inu/resman/resource.py:209, in ResourceModel.__init__(self, name, **cfg)
#     207     if cfg and self._manager.is_listed(name):  # already registered under name
#     208         _log.warning(f"Creating resource {self._kind_name} with already registered {name=}!")
# --> 209     super().__init__(name=name, **cfg)
#     211 assert hasattr(self, self._file_info_attr)
#
# File ~/miniconda3/envs/algodev/lib/python3.11/site-packages/pydantic/main.py:339, in BaseModel.__init__(__pydantic_self__, **data)
#     333 """
#     334 Create a new model by parsing and validating input data from keyword arguments.
#     335
#     336 Raises ValidationError if the input data cannot be parsed to form a valid model.
#     337 """
#     338 # Uses something other than `self` the first arg to allow "self" as a settable attribute
# --> 339 values, fields_set, validation_error = validate_model(__pydantic_self__.__class__, data)
#     340 if validation_error:
#     341     raise validation_error
#
# File ~/miniconda3/envs/algodev/lib/python3.11/site-packages/pydantic/main.py:1074, in validate_model(model, input_data, cls)
#    1071     if check_extra:
#    1072         names_used.add(field.name if using_name else field.alias)
# -> 1074 v_, errors_ = field.validate(value, values, loc=field.alias, cls=cls_)
#    1075 if isinstance(errors_, ErrorWrapper):
#    1076     errors.append(errors_)
#
# File ~/miniconda3/envs/algodev/lib/python3.11/site-packages/pydantic/fields.py:864, in ModelField.validate(self, v, values, loc, cls)
#     862 errors: Optional['ErrorList']
#     863 if self.pre_validators:
# --> 864     v, errors = self._apply_validators(v, values, loc, cls, self.pre_validators)
#     865     if errors:
#     866         return v, errors
#
# File ~/miniconda3/envs/algodev/lib/python3.11/site-packages/pydantic/fields.py:1154, in ModelField._apply_validators(self, v, values, loc, cls, validators)
#    1152 for validator in validators:
#    1153     try:
# -> 1154         v = validator(cls, v, values, self, self.model_config)
#    1155     except (ValueError, TypeError, AssertionError) as exc:
#    1156         return v, ErrorWrapper(exc, loc)
#
# File ~/miniconda3/envs/algodev/lib/python3.11/site-packages/pydantic/class_validators.py:304, in _generic_validator_cls.<locals>.<lambda>(cls, v, values, field, config)
#     302     return lambda cls, v, values, field, config: validator(cls, v, values=values, field=field, config=config)
#     303 elif args == set():
# --> 304     return lambda cls, v, values, field, config: validator(cls, v)
#     305 elif args == {'values'}:
#     306     return lambda cls, v, values, field, config: validator(cls, v, values=values)
#
# File /sp/code/algodev/inu/pipelines/benchmark/core.py:320, in BenchmarkRM.fill_inputs(cls, v)
#     317 @validator('inputs', pre=True)
#     318 def fill_inputs(cls, v):
#     319     if isinstance(v, str):
# --> 320         v = CollectionRM.find_resource(v, fail=True)
#     321     return v
#
# File /sp/code/algodev/inu/resman/resource.py:297, in ResourceModel.find_resource(cls, name, as_cfg, auto_scan, fail, valid)
#     283 @classmethod
#     284 def find_resource(cls: RT, name: str, *,
#     285                   as_cfg=False, auto_scan: AutoScan = 'first', fail=False,
#     286                   valid: bool | dict[Type[ResourceModel], list[str]] = True
#     287                   ) -> RT | None:
#     288     """
#     289     If resource registered under the given `name` is found - return it, otherwise `None`.
#     290
#    (...)
#     295     :param auto_scan: [always, never, first, empty] - conditions to allow to folders rescan if not found.
#     296     """
# --> 297     return cls._manager.find_resource(name, as_cfg=as_cfg, valid=valid, fail=fail, auto_scan=auto_scan)
#
# File /sp/code/algodev/inu/resman/resource.py:815, in ResManager.find_resource(self, name, valid, fail, as_cfg, auto_scan, fuzzy)
#     813 if fail:
#     814     available = ', '.join(self.list('name'))
# --> 815     raise ResNotFoundError(f"No {self.model._kind_name} with {name=} among {available = }")
#
# ResNotFoundError: No Collection with name='DISP_EVAL_SYNTH' among available = 'KITTI'

# %%
dc = bm.evaluated_ds().qix(scene=['A_0000_0007', 'B_0047_0012', 'C_0034_0010', 'C_0095_0011', 'A_0000_0009'], as_dc=True) # DataCollection
issues = IssueCollection.from_csv('~/code/algodev/resources/issues/selector_issues.csv')

# %%
from inu.pipelines.adapters.disparity.visual import comp_sel_warp_missed_bad_dpe

vis = lambda _ : comp_sel_warp_missed_bad_dpe(_, alg_name, out='all')
# vis = lambda _ : imgrid(_.GT.L, out='all')

# %%
# import matplotlib.pyplot as plt
# fig = plt.figure()
# axs = fig.subplots
# fig, axes = plt.subplots()
# fig.canvas.supports_blit

# %% [markdown]
# #### Use Case 1 - Show one scene of one alg (one or more axes), then annotate

# %%
scene_lbls = Labels(dataset='FT3D', scene='A_0000_0007', )

axes_queries = [(0, scene_lbls), (2, scene_lbls)]
vis_outs = vis(dc.qix(**scene_lbls, trans=True))
# vis_issue = VisIssue(issues, vis_outs.fig, axes_queries, scene_lbls | dict(alg=alg_name))
vis_issue = VisIssue(issues, vis_outs.fig, axes_queries, scene_lbls )

vis_issue.show()

# %% [markdown]
# #### Use Case 2: Show one scene (one or more axes) for two alg

# %%
# ToDO In Imgrid - Include all labels of image inside the ax
scene_lbls = Labels(dataset='FT3D', scene='A_0000_0007', )
axes_queries = [(0, scene_lbls | dict(alg=alg_name)), (1, scene_lbls | dict(alg='TEST'))]

vis_two_ims = lambda _ : imgrid(_.GT.L, _.GT.L,  out='all')
vis_outs = vis_two_ims(dc.qix(**scene_lbls, trans=True))

vis_issue = VisIssue(issues, vis_outs.fig, axes_queries)
vis_issue.show()

# %% [markdown]
# #### Use Case 3: Show specific issues on their **relevant** scenes

# %%
specific_issues = issues.qix(issue_type=['S2', 'S4'])
show_issues_on_scenes(specific_issues, dc=dc, vis=vis, axes_queries=[3])

# %% [markdown]
# #### Use Case 4: After showing all scenes, Show specific issues on them ( for one alg)

# %%
for scene_labels, scene_imgs in dc.iter(group=['dataset', 'scene']):
    scene_imgs = scene_imgs.fetch()
    vis_outs = vis(scene_imgs)
    VisIssue.attach_labels(vis_outs.fig.axes, labels=scene_labels)
    vis_issue = VisIssue(issues.qix(alg_name, issue_type=['S2', 'S4']), vis_outs.fig)
    vis_issue.show()
